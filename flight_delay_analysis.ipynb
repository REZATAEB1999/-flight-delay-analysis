# %%
import pandas as pd

df = pd.read_csv("airtravel.csv")
df.head()
# Out:
#   Month   "1958"   "1959"   "1960"
# 0   JAN      340      360      417
# 1   FEB      318      342      391
# 2   MAR      362      406      419
# 3   APR      348      396      461
# 4   MAY      363      420      472

# %%
import matplotlib.pyplot as plt

df.plot(x='Month', kind='bar', figsize=(10, 6))
plt.title('Monthly Air Travel (1958–1960)')
plt.ylabel('Passengers')
plt.xlabel('Month')
plt.grid(True)
plt.tight_layout()
plt.show()
